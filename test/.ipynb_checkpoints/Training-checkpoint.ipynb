# %%
import numpy as np
import h5py
import torch
#from torch.utils.data import Dataset, DataLoader
# import torch.utils.data as data
import torch.utils.data as data_utils
from torch.utils.data.dataset import random_split
import numpy as np
from torch.autograd import Variable
import torch.nn as nn
import torch.optim as optim
# Out:
# /Users/wilsonchang/Desktop/Project/test/.env/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# helper functions

# make minibatch for training
def minibatch(X, y, batch_size=50):
    X = X.data.numpy()
    y = y.data.numpy()
    N = X.shape[0]
    batch_mask = np.random.choice(N, batch_size)
    X_batch = X[batch_mask]
    y_batch = y[batch_mask]
    return Variable(torch.Tensor(X_batch)), Variable(torch.Tensor(y_batch))

# %% [markdown]
# Helper Clases

# %%
class EEGDataset(data_utils.Dataset):
    """EEG dataset."""
    def __init__(self, X, y):
        self.X = X;
        self.y = y;
    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]
    
class Flatten(nn.Module):
    def forward(self, x):
        N, E, T = x.size() 
        return x.view(N, -1)

# %% [markdown]
# Load Data

# %%
A01T = h5py.File('project_datasets/A01T_slice.mat', 'r')
print (A01T)
X = np.copy(A01T['image'])
y = np.copy(A01T['type'])
X = X[:, 0:23, :] # only goes to 23 since you dont use last 3 channels
# X = np.moveaxis(X, -1, 0)
y = y[0,0:X.shape[0]:1]
#y = np.asarray(y, dtype=np.int32)
#subtract 769 so classes start at 0
y = y - 769
print (np.shape(X))
# Out:
# <HDF5 file "A01T_slice.mat" (mode r)>
# (288, 23, 1000)

# %%
data = EEGDataset(X,y)
dset = {}
dset['train'], dset['val'], dset['test'] = random_split(data, [len(data)-100, 50, 50])
#num_workers for GPU stuff
#dataloaders = {x: data_utils.DataLoader(dset[x], batch_size=10, shuffle=True, num_workers=1) for x in ['train', 'val', 'test']}
dataloaders = {x: data_utils.DataLoader(dset[x], batch_size=50, shuffle=True, num_workers=4) for x in ['train', 'val', 'test']}

channels = 23
classes = 4
#for i_batch, sample_batched in enumerate(dataloaders['train']):
#    X, y = sample_batched
#    print (X)

# %%
# toy data
#N, E, T= 200, 10, 100
#C = 4
#X_train = Variable(torch.randn(T, N, E))

#y = np.random.randint(0, 4, size=100)
#y = Variable(torch.Tensor(y), requires_grad=False)
#y_train = Variable(torch.LongTensor(N).random_(0, C-1))
#actual = y_train.data.numpy()
#X.type(dtype)
#y.type(dtype)

# %%
dtype = torch.DoubleTensor
model = nn.Sequential(
    nn.LSTM(channels, classes, 2)
)
model.type(dtype)
loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.Adam(model.parameters(), lr=1e-2)

# %%
#training

num_epochs = 10
batch_size = 10

#iterations_per_epoch = N//batch_size
best_val_acc = 0
train_acc_at_best_val = 0

#for epoch in range(1):
for epoch in range(num_epochs):
    #for t in range(iterations_per_epoch):
    for i, sample_batched in enumerate(dataloaders['train']):
        
        X_train, y_train = sample_batched
        # Flip axis first
        X_train = torch.Tensor(np.moveaxis(X_train.numpy(), -1, 0))
        X_train = Variable(X_train, requires_grad=True).type(dtype)
        y_train = Variable(y_train).long()
        
        # Calculate the loss
        scores, _ = model(X_train)
        _, y_pred = torch.max(scores, 0)
        y_pred = Variable(y_pred.data, requires_grad=True)
        y_pred = y_pred.type(dtype)
        loss = loss_fn(y_pred, y_train)
        print (loss)
        print('(%d batch) loss: %f' % (i, loss))
        # Do backpropagation
        model.zero_grad()
        loss.backward()
        for f in model.parameters():
            print('grad is')
            print(f.grad)
        # Update the parameters
        optimizer.step()
        ## Training Accuracy After 1 epoch
    y_pred_tot = []
    y_train_tot = []
    for i_batch, sample_batched in enumerate(dataloaders['train']):
        X_train, y_train = sample_batched
        # Flip axis first
        X_train = torch.Tensor(np.moveaxis(X_train.numpy(), -1, 0))
        X_train = Variable(X_train, requires_grad=True).type(dtype)
        y_train = Variable(y_train).long()
        # Calculate the loss
        scores, _ = model(X_train)
        _, y_pred = torch.max(scores, 0)
        _, y_pred = torch.max(y_pred, 1)
        y_pred_tot.append(y_pred.data.numpy())
        y_train_tot.append(y_train.data.numpy())    
    train_acc = np.mean(np.concatenate(y_pred_tot) == np.concatenate(y_train_tot))
        ## Validation Accuracy After 1 epoch    
    y_pred_tot = []
    y_val_tot = []
    for i_batch, sample_batched in enumerate(dataloaders['val']):
        X_val, y_val = sample_batched
        # Flip axis first
        X_val = torch.Tensor(np.moveaxis(X_val.numpy(), -1, 0))
        X_val = Variable(X_val, requires_grad=True).type(dtype)
        y_val = Variable(y_val).long()
        # Calculate the loss
        scores, _ = model(X_val)
        _, y_pred = torch.max(scores, 0)
        _, y_pred = torch.max(y_pred, 1)
        y_pred_tot.append(y_pred.data.numpy())
        y_val_tot.append(y_val.data.numpy())
    val_acc = np.mean(np.concatenate(y_pred_tot) == np.concatenate(y_val_tot))
    print('(Epoch %d / %d) train acc: %f; val_acc: %f' % (epoch+1, num_epochs, train_acc, val_acc))
# Out:
# Variable containing:
#  305.4956
# [torch.DoubleTensor of size 1]
#
# (0 batch) loss: 305.495580
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  310.0309
# [torch.DoubleTensor of size 1]
#
# (1 batch) loss: 310.030905
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  386.8023
# [torch.DoubleTensor of size 1]
#
# (2 batch) loss: 386.802329
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  219.8380
# [torch.DoubleTensor of size 1]
#
# (3 batch) loss: 219.838046
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# (Epoch 1 / 10) train acc: 0.202128; val_acc: 0.260000
# Variable containing:
#  285.0345
# [torch.DoubleTensor of size 1]
#
# (0 batch) loss: 285.034482
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  395.9098
# [torch.DoubleTensor of size 1]
#
# (1 batch) loss: 395.909799
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  276.4459
# [torch.DoubleTensor of size 1]
#
# (2 batch) loss: 276.445866
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  278.9679
# [torch.DoubleTensor of size 1]
#
# (3 batch) loss: 278.967870
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# (Epoch 2 / 10) train acc: 0.202128; val_acc: 0.260000
# Variable containing:
#  302.8117
# [torch.DoubleTensor of size 1]
#
# (0 batch) loss: 302.811750
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  317.7032
# [torch.DoubleTensor of size 1]
#
# (1 batch) loss: 317.703178
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  298.0357
# [torch.DoubleTensor of size 1]
#
# (2 batch) loss: 298.035708
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  330.0725
# [torch.DoubleTensor of size 1]
#
# (3 batch) loss: 330.072491
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# (Epoch 3 / 10) train acc: 0.202128; val_acc: 0.260000
# Variable containing:
#  255.4492
# [torch.DoubleTensor of size 1]
#
# (0 batch) loss: 255.449190
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  360.0480
# [torch.DoubleTensor of size 1]
#
# (1 batch) loss: 360.047982
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  300.6505
# [torch.DoubleTensor of size 1]
#
# (2 batch) loss: 300.650544
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  333.2342
# [torch.DoubleTensor of size 1]
#
# (3 batch) loss: 333.234227
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# (Epoch 4 / 10) train acc: 0.202128; val_acc: 0.260000
# Variable containing:
#  251.1418
# [torch.DoubleTensor of size 1]
#
# (0 batch) loss: 251.141846
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  326.6245
# [torch.DoubleTensor of size 1]
#
# (1 batch) loss: 326.624513
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  344.0501
# [torch.DoubleTensor of size 1]
#
# (2 batch) loss: 344.050055
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  325.7754
# [torch.DoubleTensor of size 1]
#
# (3 batch) loss: 325.775414
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# (Epoch 5 / 10) train acc: 0.202128; val_acc: 0.260000
# Variable containing:
#  326.0752
# [torch.DoubleTensor of size 1]
#
# (0 batch) loss: 326.075220
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  300.5297
# [torch.DoubleTensor of size 1]
#
# (1 batch) loss: 300.529679
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  308.1515
# [torch.DoubleTensor of size 1]
#
# (2 batch) loss: 308.151515
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  308.7491
# [torch.DoubleTensor of size 1]
#
# (3 batch) loss: 308.749098
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# (Epoch 6 / 10) train acc: 0.202128; val_acc: 0.260000
# Variable containing:
#  260.4645
# [torch.DoubleTensor of size 1]
#
# (0 batch) loss: 260.464535
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  375.7956
# [torch.DoubleTensor of size 1]
#
# (1 batch) loss: 375.795581
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  312.9826
# [torch.DoubleTensor of size 1]
#
# (2 batch) loss: 312.982561
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  289.6882
# [torch.DoubleTensor of size 1]
#
# (3 batch) loss: 289.688226
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# (Epoch 7 / 10) train acc: 0.202128; val_acc: 0.260000
# Variable containing:
#  330.6256
# [torch.DoubleTensor of size 1]
#
# (0 batch) loss: 330.625614
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  317.2157
# [torch.DoubleTensor of size 1]
#
# (1 batch) loss: 317.215708
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  299.1618
# [torch.DoubleTensor of size 1]
#
# (2 batch) loss: 299.161846
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  292.6349
# [torch.DoubleTensor of size 1]
#
# (3 batch) loss: 292.634948
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# (Epoch 8 / 10) train acc: 0.202128; val_acc: 0.260000
# Variable containing:
#  323.4767
# [torch.DoubleTensor of size 1]
#
# (0 batch) loss: 323.476681
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  272.5643
# [torch.DoubleTensor of size 1]
#
# (1 batch) loss: 272.564278
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  311.2627
# [torch.DoubleTensor of size 1]
#
# (2 batch) loss: 311.262689
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  344.8712
# [torch.DoubleTensor of size 1]
#
# (3 batch) loss: 344.871158
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# (Epoch 9 / 10) train acc: 0.202128; val_acc: 0.260000
# Variable containing:
#  310.0909
# [torch.DoubleTensor of size 1]
#
# (0 batch) loss: 310.090906
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  316.9032
# [torch.DoubleTensor of size 1]
#
# (1 batch) loss: 316.903179
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  351.6238
# [torch.DoubleTensor of size 1]
#
# (2 batch) loss: 351.623790
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# Variable containing:
#  251.0367
# [torch.DoubleTensor of size 1]
#
# (3 batch) loss: 251.036650
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# grad is
# None
# (Epoch 10 / 10) train acc: 0.202128; val_acc: 0.260000

# %%
y_pred = model(X_train)
loss = loss_fn(last_output, y_train)
print (loss)
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ded6332cb9c3> in <module>()
#       1 y_pred = model(X_train)
# ----> 2 loss = loss_fn(last_output, y_train)
#       3 print (loss)
#       4 model
#
# NameError: name 'last_output' is not defined
